# %% [markdown]
# ## Box Plot

# %% [markdown]
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# f = sns.load_dataset(" ")
#
# sns.boxplot(x="",y="",data=f)
#
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
var = sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var)
plt.show()

# %%
## hue mathod 
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="time")
plt.show()

# %%
## hue mathod 
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex")
plt.show()

# %%
## color
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\3242248827.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g")

# %%
## order parameter used for change the order
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g", order=["Fri","Sun","Thu","Sat"])
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\1022839999.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g", order=["Fri","Sun","Thu","Sat"])

# %%
## showmeans show the median value
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g", order=["Fri","Sun","Thu","Sat"],
            showmeans=True)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\2659007532.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="g", order=["Fri","Sun","Thu","Sat"],

# %%
## meanprops method 
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="w", order=["Fri","Sun","Thu","Sat"],
            showmeans=True,meanprops={"marker":"+","markeredgecolor":"b"})
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\709966034.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:w'` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=var,hue="sex",color="w", order=["Fri","Sun","Thu","Sat"],

# %%
## linewidth
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,color="w", order=["Fri","Sun","Thu","Sat"],
            showmeans=True,meanprops={"marker":"+","markeredgecolor":"b"},linewidth=3)
plt.show()

# %%
# palette parameter used for giving a color.
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=var,order=["Fri","Sun","Thu","Sat"],
            showmeans=True,meanprops={"marker":"+","markeredgecolor":"b"},linewidth=3,palette="plasma")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\795822925.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=var,order=["Fri","Sun","Thu","Sat"],

# %%
# horizontal data
sns.set(style="whitegrid")
sns.boxplot(x="total_bill",y="day",data=var,order=["Fri","Sun","Thu","Sat"],
            showmeans=True,meanprops={"marker":"+","markeredgecolor":"b"},linewidth=3,
            palette="plasma")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_8536\139615995.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="total_bill",y="day",data=var,order=["Fri","Sun","Thu","Sat"],

# %%
sns.set(style="whitegrid")
sns.boxplot(data=var,
            showmeans=True,meanprops={"marker":"+","markeredgecolor":"b"},linewidth=3,
            palette="plasma",orient="h")
plt.show()

# %%
sns.set(style="whitedrid")

sns.boxplot(x=var["total_bill"])

plt.show()
