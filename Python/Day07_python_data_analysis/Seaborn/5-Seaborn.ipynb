# %% [markdown]
# ## Seaborn Scatter Plot

# %% [markdown]
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# data = sns.load_dataset(" ")
#
# sns.scatterplot(x="",y="",data="")
#
# plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
var = sns.load_dataset("penguins")
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var)
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex")
plt.show()

# %%
var = sns.load_dataset("penguins").head(20)
var
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex")
plt.show()

# %%
## change the style using style parameter
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex")
plt.show()

# %%
## size parameter

sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex")
plt.show()

# %%
## sizes parameter

sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex",
                sizes=[200,100])
plt.show()

# %%
## palette parameter for colour

sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex",
                sizes=[200,100],palette="gist_ncar")
plt.show()

# %%
## alpha parameter for reduce the colour

sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex",
                sizes=[200,100],palette="gist_ncar",alpha=0.6)
plt.show()

# %%
## marker parameter
m={"Male":"+","Female":"o"}

sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex",
                sizes=[200,100],palette="gist_ncar",markers=m)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 4
#       1 ## marker parameter
#       2 m={"Male":"+","Female":"o"}
# ----> 4 sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=var,hue="sex",style="sex",size="sex",
#       5                 sizes=[200,100],palette="gist_ncar",marker=m)
#       6 plt.show()
#
# File c:\Users\ankul\DS_ML_AI\Ankul\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\ankul\DS_ML_AI\Ankul\Lib\site-packages\seaborn\relational.py:433, in _ScatterPlotter.plot(self, ax, kws)
#     430 m = kws.get("marker", mpl.rcParams.get("marker", "o"))
#     431 if not isinstance(m, mpl.markers.MarkerStyle):
#     432     # TODO in more recent matplotlib (which?) can pass a MarkerStyle here
# --> 433     m = mpl.markers.MarkerStyle(m)
#     434 if m.is_filled():
#     435     kws.setdefault("edgecolor", "w")
#
# File c:\Users\ankul\DS_ML_AI\Ankul\Lib\site-packages\matplotlib\markers.py:248, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247 self._set_fillstyle(fillstyle)
# --> 248 self._set_marker(marker)
#
# File c:\Users\ankul\DS_ML_AI\Ankul\Lib\site-packages\matplotlib\markers.py:320, in MarkerStyle._set_marker(self, marker)
#     317 elif isinstance(marker, Path):
#     318     self._marker_function = self._set_path_marker
#     319 elif (isinstance(marker, Sized) and len(marker) in (2, 3) and
# --> 320         marker[1] in (0, 1, 2)):
#     321     self._marker_function = self._set_tuple_marker
#     322 elif isinstance(marker, MarkerStyle):
#
# KeyError: 1
