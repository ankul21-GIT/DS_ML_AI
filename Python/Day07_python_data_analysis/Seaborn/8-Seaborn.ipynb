# %% [markdown]
# ## Violin Plot in Seaborn

# %% [markdown]
# A violin plot play a similar role as a box and whisker plot. It shows the distribution of quabtitative data across several level of one (or more) catogorical variable such that those distribution can be compared.

# %% [markdown]
# import seaborn as sns
#
# seaborn.set(style="whitegrid")
#
# f = seabron.load_dataset("fmri")
#
# seaborn.violinplot(x=" ",y=" ",data=f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
var = sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x="day",y="total_bill",data=var)
plt.show()

# %%
## hue method

sns.violinplot(x="day",y="total_bill",data=var,hue="time")
plt.show()

# %%
## linewidth parameter

sns.violinplot(x="day",y="total_bill",data=var,linewidth=3)
plt.show()

# %%
## palette paeameter use for giving the color


sns.violinplot(x="day",y="total_bill",data=var,linewidth=3,palette="Dark2")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\1294233621.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day",y="total_bill",data=var,linewidth=3,palette="Dark2")

# %%
sns.violinplot(x="time",y="total_bill",data=var,order=["lunch","dinner"],palette="Dark2")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\1581640163.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="time",y="total_bill",data=var,palette="Dark2")

# %%
sns.violinplot(x="time",y="total_bill",data=var,palette="Dark2",saturation=0.4)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\2802622464.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="time",y="total_bill",data=var,palette="Dark2",saturation=0.4)

# %%
sns.violinplot(x="time",y="total_bill",data=var,color="r")
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True)
plt.show()

# %%
# scale parameter
sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\3513624116.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width")

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width",inner="quart")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\1276379657.py:1: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width",inner="quart")

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width",inner="stick")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_16864\1796865159.py:1: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x="day",y="total_bill",data=var,hue="sex",split=True,scale="width",inner="stick")

# %%
## if you wanna print singl violing plot of the total bill
sns.violinplot(x=var["total_bill"])
plt.show()
