# %% [markdown]
# ## Styling plot in Seaborn

# %% [markdown]
# - Seaborn figure style
#
# - Removing Axes Spines
#
# - Scale and context

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
var = sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(y=var["total_bill"])
plt.show()

# %%
sns.barplot(x="day",y="total_bill",data=var)
plt.show()

# %%
c = ["r","g","b","y"]
sns.barplot(x="day",y="total_bill",data=var,palette=c)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_11916\789336234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day",y="total_bill",data=var,palette=c)

# %%
## grid method
c = ["r","g","b","y"]
sns.barplot(x="day",y="total_bill",data=var,palette=c)
plt.grid()
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_11916\2799761639.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day",y="total_bill",data=var,palette=c)

# %%
sns.barplot(x="day",y="total_bill",data=var)
plt.grid()
plt.show()

# %%
## how to change the background
sns.set_style("dark")
sns.barplot(x="day",y="total_bill",data=var)
plt.show()

# %%
## how to change the background
sns.set_style("darkgrid")
sns.barplot(x="day",y="total_bill",data=var)
plt.grid()
plt.show()

# %% [markdown]
# Remove axes spine

# %%
## we use despine parameter to remove axis
sns.set_style("white")
sns.barplot(x="day",y="total_bill",data=var)
sns.despine()
plt.show()

# %% [markdown]
# Scale and Context

# %%
# Scale

# increase and decrease figsize

sns.set_style("white")
plt.figure(figsize=(12,4))

sns.barplot(x="day",y="total_bill",data=var)

sns.despine()

plt.show()

# %%
## content

sns.set_style("white")
sns.set_context("poster",font_scale=2)

sns.barplot(x="day",y="total_bill",data=var)

plt.show()

# %%
## color


sns.barplot(x="day",y="total_bill",data=var,palette="cool")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_11916\377524913.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day",y="total_bill",data=var,palette="cool")
