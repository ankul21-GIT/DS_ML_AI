# %% [markdown]
# ## Seaborn Strip Plot

# %% [markdown]
# Strip plot is very simple to understand. It is basically a scatter plot that differentiates different catogories. Strip plot are considerd a good alternative to a box plot or a violin plot.

# %% [markdown]
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# tip = sns.load_dataset(" ")
#
# sns.stripplot(x="",y="",data=tip)
#
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
var = sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x="day",y="total_bill",data=var)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.stripplot(x="day",y="total_bill",data=var)
#       2 plt.show()
#
# NameError: name 'var' is not defined

# %%
sns.stripplot(x="day",y="total_bill",data=var, hue="sex")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.stripplot(x="day",y="total_bill",data=var, hue="sex")
#       2 plt.show()
#
# NameError: name 'var' is not defined

# %%
## palatte color parameter
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r")
plt.show()

# %%
## linewidth
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 ## linewidth
# ----> 2 sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1)
#       3 plt.show()
#
# NameError: name 'var' is not defined

# %%
## edgecolor
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1,edgecolor="r")
plt.show()

# %%
## jitter parameter

sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1,
              edgecolor="r",jitter=0.4)
plt.show()

# %%
## size parameter for increse the size
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1,
              edgecolor="r",size=15)
plt.show()

# %%
# marker parameter
m={"Male":"o","female":">"}
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1,
              edgecolor="r",marker="<")
plt.show()

# %%
## alpha

m={"Male":"o","female":">"}
sns.stripplot(x="day",y="total_bill",data=var, hue="sex", palette="rocket_r",linewidth=1,
              edgecolor="r",marker="<", alpha=0.4)
plt.show()

# %%
var = sns.stripplot(x=var["total_bill"])
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 var = sns.stripplot(x=var["total_bill"])
#       2 var
#
# NameError: name 'var' is not defined
