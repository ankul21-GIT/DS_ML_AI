# %% [markdown]
# ## Seaborn Bar Plot

# %% [markdown]
# import seaborn as sns
#
#
# import matplotlib.pyplot as plt
#
# df = sns.load_dataset(" ")
#
# sns.barplot(df[" "])
#
# plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
var = sns.load_dataset("penguins")
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x=var.island, y=var.bill_length_mm)
plt.show()

# %%
sns.barplot(x="island", y="bill_length_mm",data=var)
plt.show()

# %%
# hue parameter is used to seprate the data.
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex")
plt.show()

# %%
## how to change the order

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1)
plt.show()

# %%
## hue_order 
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"])
plt.show()

# %%
## ci parameter confidenceinterval

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"],ci=100)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\2568511013.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,

# %%
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"],ci=100,n_boot=1)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\2376659017.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,

# %%
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="bill_length_mm", y="bill_depth_mm",data=var, orient="h")
plt.show()

# %%
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var,color="g")
plt.show()

# %%
## palette method is used for giving the color
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"],palette="icefire")
plt.show()

# %%
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"])
plt.show()

# %%
## saturation parameter is used for reduce the color

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"],saturation=0.4)
plt.show()

# %%
## errcolor and how to increase errwidth

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"], errcolor="y")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\1749421065.py:4: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,

# %%
## errcolor and how to increase errwidth

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"], errcolor="y",errwidth=3)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\4043502064.py:4: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\4043502064.py:4: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 3}` instead.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,

# %%
## capsize

## give size to the cap

order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"],capsize=0.6)
plt.show()

# %%
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"], errcolor="y",alpha=0.4)
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_6768\3719896516.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,

# %%
## grid and darkgrid method
sns.set(style="dark")
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"])
plt.show()

# %%
## grid and darkgrid method
sns.set(style="darkgrid")
order1 = ["Dream","Torgersen","Biscoe"]
sns.barplot(x="island", y="bill_length_mm",data=var, hue="sex", order=order1,
            hue_order=["Female","Male"])
plt.show()
