# %% [markdown]
# ## Handling and Missing data (dropna & fillna)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csve.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
## dropna method is used for delete a NaN rows
df.dropna()
# Out:
#                                SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                          Electrotherm        473907.0        9457.0
# 1   N. B. I. Industrial Finance Company          5754.0         154.0
# 2               Hindcon Private Limited        304759.0        9248.0
# 3                           GKW Limited         21375.0         711.0
# 5             Alphageo (India) Limited         232755.0        8356.0
# 7      Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 10              Nahar Poly Film Limited        600043.0       38574.0
# 11       Poddar Housing and Development         46040.0        3012.0
# 12                         Linc Limited         60551.0        4076.0
# 14      Pudumjee Paper Products Limited       1316284.0      102646.0
# 15           Dynacons System & Solution        263641.0       23439.0
# 16      Andrew Yule & Company & Limited       2408026.0      230048.0
# ...

# %%
## dropna method delete to columns usin axis=1 method
df.dropna(axis=1)
# Out:
#                                     SECURITY
# 0                               Electrotherm
# 1        N. B. I. Industrial Finance Company
# 2                    Hindcon Private Limited
# 3                                GKW Limited
# 4            21st Century Management Service
# 5                  Alphageo (India) Limited
# 6                Uniphos Enterprised Limited
# 7           Jagsonpal Pharmaceutical Limited
# 8   SKM Egg Products Exportsn(India) Limited
# 9              Swelect Energy System Limited
# 10                   Nahar Poly Film Limited
# 11            Poddar Housing and Development
# 12                              Linc Limited
# 13                       Shiva Mills Limited
# 14           Pudumjee Paper Products Limited
# 15                Dynacons System & Solution
# 16           Andrew Yule & Company & Limited
# 17                     Laxmi Costpin Limited
# 18          Rudrabhishek Enterprises Limited
# 19             PIL ITALICA LIFESTYLE LIMITED
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
## how=all parameter only use when all the rows or column are Null(Nan) the can remevoe it.
df.dropna(how='all')
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
# Out:
#                                SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                          Electrotherm        473907.0        9457.0
# 1   N. B. I. Industrial Finance Company          5754.0         154.0
# 2               Hindcon Private Limited        304759.0        9248.0
# 3                           GKW Limited         21375.0         711.0
# 5             Alphageo (India) Limited         232755.0        8356.0
# 7      Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 10              Nahar Poly Film Limited        600043.0       38574.0
# 11       Poddar Housing and Development         46040.0        3012.0
# 12                         Linc Limited         60551.0        4076.0
# 14      Pudumjee Paper Products Limited       1316284.0      102646.0
# 15           Dynacons System & Solution        263641.0       23439.0
# 16      Andrew Yule & Company & Limited       2408026.0      230048.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
df.dropna(subset=['CHANGE'])
# Out:
#                                SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                          Electrotherm        473907.0        9457.0
# 1   N. B. I. Industrial Finance Company          5754.0         154.0
# 2               Hindcon Private Limited        304759.0        9248.0
# 3                           GKW Limited         21375.0         711.0
# 5             Alphageo (India) Limited         232755.0        8356.0
# 6           Uniphos Enterprised Limited        162601.0           NaN
# 7      Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 9         Swelect Energy System Limited             NaN       12276.0
# 10              Nahar Poly Film Limited        600043.0       38574.0
# 11       Poddar Housing and Development         46040.0        3012.0
# 12                         Linc Limited         60551.0        4076.0
# 14      Pudumjee Paper Products Limited       1316284.0      102646.0
# ...

# %%
## inplace=True it create new parameter
df.dropna(inplace=True)
df
# Out:
#                                SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                          Electrotherm        473907.0        9457.0
# 1   N. B. I. Industrial Finance Company          5754.0         154.0
# 2               Hindcon Private Limited        304759.0        9248.0
# 3                           GKW Limited         21375.0         711.0
# 5             Alphageo (India) Limited         232755.0        8356.0
# 7      Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 10              Nahar Poly Film Limited        600043.0       38574.0
# 11       Poddar Housing and Development         46040.0        3012.0
# 12                         Linc Limited         60551.0        4076.0
# 14      Pudumjee Paper Products Limited       1316284.0      102646.0
# 15           Dynacons System & Solution        263641.0       23439.0
# 16      Andrew Yule & Company & Limited       2408026.0      230048.0
# ...

# %%
## thresh parameter romove if there is a single null value and you want to remove it give threse=1.
df.dropna(thresh=1)
# Out:
#                                SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                          Electrotherm        473907.0        9457.0
# 1   N. B. I. Industrial Finance Company          5754.0         154.0
# 2               Hindcon Private Limited        304759.0        9248.0
# 3                           GKW Limited         21375.0         711.0
# 5             Alphageo (India) Limited         232755.0        8356.0
# 7      Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 10              Nahar Poly Film Limited        600043.0       38574.0
# 11       Poddar Housing and Development         46040.0        3012.0
# 12                         Linc Limited         60551.0        4076.0
# 14      Pudumjee Paper Products Limited       1316284.0      102646.0
# 15           Dynacons System & Solution        263641.0       23439.0
# 16      Andrew Yule & Company & Limited       2408026.0      230048.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
df.fillna("python")
# Out:
#                                     SECURITY TODAY - VILUME AVG - VOLUME  \
# 0                               Electrotherm       473907.0       9457.0
# 1        N. B. I. Industrial Finance Company         5754.0        154.0
# 2                    Hindcon Private Limited       304759.0       9248.0
# 3                                GKW Limited        21375.0        711.0
# 4            21st Century Management Service       110375.0       3879.0
# 5                  Alphageo (India) Limited        232755.0       8356.0
# 6                Uniphos Enterprised Limited       162601.0       python
# 7           Jagsonpal Pharmaceutical Limited      1301892.0      73134.0
# 8   SKM Egg Products Exportsn(India) Limited      1541130.0      87775.0
# 9              Swelect Energy System Limited         python      12276.0
# 10                   Nahar Poly Film Limited       600043.0      38574.0
# 11            Poddar Housing and Development        46040.0       3012.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
df.fillna({"SECURITY":"Python","TODAY - VILUME":"Java", "AVG - VOLUME":"C"})
# Out:
#                                     SECURITY TODAY - VILUME AVG - VOLUME  \
# 0                               Electrotherm       473907.0       9457.0
# 1        N. B. I. Industrial Finance Company         5754.0        154.0
# 2                    Hindcon Private Limited       304759.0       9248.0
# 3                                GKW Limited        21375.0        711.0
# 4            21st Century Management Service       110375.0       3879.0
# 5                  Alphageo (India) Limited        232755.0       8356.0
# 6                Uniphos Enterprised Limited       162601.0            C
# 7           Jagsonpal Pharmaceutical Limited      1301892.0      73134.0
# 8   SKM Egg Products Exportsn(India) Limited      1541130.0      87775.0
# 9              Swelect Energy System Limited           Java      12276.0
# 10                   Nahar Poly Film Limited       600043.0      38574.0
# 11            Poddar Housing and Development        46040.0       3012.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
## metho=ffill is know as forward filling it copy the above data
df.fillna(method="ffill")
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_33972\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0        8356.0
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
## metho=bfill is know as backward filling it copy the below data automatically.
df.fillna(method="bfill")
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_33972\942181770.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0       73134.0
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
df.fillna(method="bfill", axis=1)
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_33972\177786797.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill", axis=1)
# C:\Users\ankul\AppData\Local\Temp\ipykernel_33972\177786797.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(method="bfill", axis=1)
#                                     SECURITY TODAY - VILUME AVG - VOLUME  \
# 0                               Electrotherm       473907.0       9457.0
# 1        N. B. I. Industrial Finance Company         5754.0        154.0
# 2                    Hindcon Private Limited       304759.0       9248.0
# 3                                GKW Limited        21375.0        711.0
# ...

# %%
df.fillna(12,inplace=True)

# %%
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0          12.0
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited            12.0       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ankul\Downloads\null.csveee.csv")
df
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm        473907.0        9457.0
# 1        N. B. I. Industrial Finance Company          5754.0         154.0
# 2                    Hindcon Private Limited        304759.0        9248.0
# 3                                GKW Limited         21375.0         711.0
# 4            21st Century Management Service        110375.0        3879.0
# 5                  Alphageo (India) Limited         232755.0        8356.0
# 6                Uniphos Enterprised Limited        162601.0           NaN
# 7           Jagsonpal Pharmaceutical Limited       1301892.0       73134.0
# 8   SKM Egg Products Exportsn(India) Limited       1541130.0       87775.0
# 9              Swelect Energy System Limited             NaN       12276.0
# 10                   Nahar Poly Film Limited        600043.0       38574.0
# ...

# %%
## print python one time in every NaN column wise because the limit is 1.
df.fillna("Python", limit=1)
# Out:
#                                     SECURITY TODAY - VILUME AVG - VOLUME  \
# 0                               Electrotherm       473907.0       9457.0
# 1        N. B. I. Industrial Finance Company         5754.0        154.0
# 2                    Hindcon Private Limited       304759.0       9248.0
# 3                                GKW Limited        21375.0        711.0
# 4            21st Century Management Service       110375.0       3879.0
# 5                  Alphageo (India) Limited        232755.0       8356.0
# 6                Uniphos Enterprised Limited       162601.0       Python
# 7           Jagsonpal Pharmaceutical Limited      1301892.0      73134.0
# 8   SKM Egg Products Exportsn(India) Limited      1541130.0      87775.0
# 9              Swelect Energy System Limited         Python      12276.0
# 10                   Nahar Poly Film Limited       600043.0      38574.0
# 11            Poddar Housing and Development        46040.0       3012.0
# ...
