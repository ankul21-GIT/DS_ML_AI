# %% [markdown]
# ## Pandas Function

# %%
import pandas as pd
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv")

# %%
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0    ELECTHERM                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
## how to get a index
csv.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
## how to get a columns
csv.columns
# Out:
# Index(['SYMBOL', 'SECURITY', 'TODAY - VILUME', 'AVG - VOLUME', 'CHANGE',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
## how to find min value and 25 percent 50 percent and 75 percent

csv.describe()
# Out:
#        TODAY - VILUME   AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  \
# count    2.500000e+01      25.000000  25.000000         0.0         0.0
# mean     8.009246e+05   71237.680000  17.900822         NaN         NaN
# std      1.395095e+06  139964.620859  10.796906         NaN         NaN
# min      5.754000e+03     154.000000   7.606862         NaN         NaN
# 25%      1.574960e+05    8356.000000  10.049911         NaN         NaN
# 50%      3.047590e+05   19069.000000  14.853673         NaN         NaN
# 75%      7.053220e+05   82307.000000  21.528002         NaN         NaN
# max      6.864080e+06  685602.000000  50.110003         NaN         NaN
#
#        Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# count         0.0         0.0         0.0          0.0
# mean          NaN         NaN         NaN          NaN
# std           NaN         NaN         NaN          NaN
# min           NaN         NaN         NaN          NaN
# ...

# %%
csv.head()
# Out:
#        SYMBOL                             SECURITY  TODAY - VILUME  \
# 0   ELECTHERM                         Electrotherm          473907
# 1      NBIFIN  N. B. I. Industrial Finance Company            5754
# 2     HINDCON              Hindcon Private Limited          304759
# 3  GKWLIMITED                          GKW Limited           21375
# 4  21STCENMGM      21st Century Management Service          110375
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  50.110003         NaN         NaN         NaN         NaN
# 1           154  37.202586         NaN         NaN         NaN         NaN
# 2          9248  32.953450         NaN         NaN         NaN         NaN
# 3           711  30.049203         NaN         NaN         NaN         NaN
# 4          3879  28.450831         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# ...

# %%
csv.head(2)
# Out:
#       SYMBOL                             SECURITY  TODAY - VILUME  \
# 0  ELECTHERM                         Electrotherm          473907
# 1     NBIFIN  N. B. I. Industrial Finance Company            5754
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  50.110003         NaN         NaN         NaN         NaN
# 1           154  37.202586         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# 1         NaN          NaN         NaN

# %%
csv.tail()
# Out:
#         SYMBOL                             SECURITY  TODAY - VILUME  \
# 20  BHAGYAPROP       Bhagyanagar Properties Limited          305594
# 21    MUNJALAU       Munjal Auto Industries Limited          705322
# 22      ALKALI               Alkalis Metals Limited          157496
# 23   INTENTECH         Intense Technologies Limited         1252606
# 24    INDORAMA  Indo Rama Synthetic (India) Limited          679204
#
#     AVG - VOLUME    CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 20         30596  9.987766         NaN         NaN         NaN         NaN
# 21         82307  8.569312         NaN         NaN         NaN         NaN
# 22         19069  8.563313         NaN         NaN         NaN         NaN
# 23        164644  7.607959         NaN         NaN         NaN         NaN
# 24         89288  7.606862         NaN         NaN         NaN         NaN
#
#     Unnamed: 9  Unnamed: 10 Unnamed: 11
# 20         NaN          NaN         NaN
# ...

# %%
csv.tail(2)
# Out:
#        SYMBOL                             SECURITY  TODAY - VILUME  \
# 23  INTENTECH         Intense Technologies Limited         1252606
# 24   INDORAMA  Indo Rama Synthetic (India) Limited          679204
#
#     AVG - VOLUME    CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 23        164644  7.607959         NaN         NaN         NaN         NaN
# 24         89288  7.606862         NaN         NaN         NaN         NaN
#
#     Unnamed: 9  Unnamed: 10 Unnamed: 11
# 23         NaN          NaN         NaN
# 24         NaN          NaN         NaN

# %%
## how to call row number 
csv[:3]
# Out:
#       SYMBOL                             SECURITY  TODAY - VILUME  \
# 0  ELECTHERM                         Electrotherm          473907
# 1     NBIFIN  N. B. I. Industrial Finance Company            5754
# 2    HINDCON              Hindcon Private Limited          304759
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  50.110003         NaN         NaN         NaN         NaN
# 1           154  37.202586         NaN         NaN         NaN         NaN
# 2          9248  32.953450         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# 1         NaN          NaN         NaN
# 2         NaN          NaN

# %%
## how to call row number 
csv[2:7]
# Out:
#        SYMBOL                         SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 2     HINDCON          Hindcon Private Limited          304759          9248
# 3  GKWLIMITED                      GKW Limited           21375           711
# 4  21STCENMGM  21st Century Management Service          110375          3879
# 5    ALPHAGEO        Alphageo (India) Limited           232755          8356
# 6    UNIENTER      Uniphos Enterprised Limited          162601          7553
#
#       CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 2  32.953450         NaN         NaN         NaN         NaN         NaN
# 3  30.049203         NaN         NaN         NaN         NaN         NaN
# 4  28.450831         NaN         NaN         NaN         NaN         NaN
# 5  27.852613         NaN         NaN         NaN         NaN         NaN
# 6  21.528002         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 10 Unnamed: 11
# 2          NaN
# ...

# %%
print(type(csv))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
## convert index number into array

csv.index.array
# Out:
# <NumpyExtensionArray>
# [ np.int64(0),  np.int64(1),  np.int64(2),  np.int64(3),  np.int64(4),
#   np.int64(5),  np.int64(6),  np.int64(7),  np.int64(8),  np.int64(9),
#  np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14),
#  np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19),
#  np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24)]
# Length: 25, dtype: int64

# %%
## how to convert it into numpy array
csv.to_numpy()
# Out:
# array([['ELECTHERM', 'Electrotherm', 473907, 9457, 50.11000282, nan, nan,
#         nan, nan, nan, nan, nan],
#        ['NBIFIN', 'N. B. I. Industrial Finance Company', 5754, 154,
#         37.20258621, nan, nan, nan, nan, nan, nan, nan],
#        ['HINDCON', 'Hindcon Private Limited', 304759, 9248, 32.95345023,
#         nan, nan, nan, nan, nan, nan, ' '],
#        ['GKWLIMITED', 'GKW Limited', 21375, 711, 30.04920337, nan, nan,
#         nan, nan, nan, nan, nan],
#        ['21STCENMGM', '21st Century Management Service', 110375, 3879,
#         28.45083129, nan, nan, nan, nan, nan, nan, nan],
#        ['ALPHAGEO', 'Alphageo (India) Limited ', 232755, 8356,
#         27.85261268, nan, nan, nan, nan, nan, nan, nan],
#        ['UNIENTER', 'Uniphos Enterprised Limited', 162601, 7553,
#         21.52800212, nan, nan, nan, nan, nan, nan, nan],
#        ['JAGSNPHARM', 'Jagsonpal Pharmaceutical Limited', 1301892, 73134,
#         17.80141977, nan, nan, nan, nan, nan, nan, nan],
# ...

# %%
## another method to create numpy array
import numpy as np
v = np.asarray(csv)
v
# Out:
# array([['ELECTHERM', 'Electrotherm', 473907, 9457, 50.11000282, nan, nan,
#         nan, nan, nan, nan, nan],
#        ['NBIFIN', 'N. B. I. Industrial Finance Company', 5754, 154,
#         37.20258621, nan, nan, nan, nan, nan, nan, nan],
#        ['HINDCON', 'Hindcon Private Limited', 304759, 9248, 32.95345023,
#         nan, nan, nan, nan, nan, nan, ' '],
#        ['GKWLIMITED', 'GKW Limited', 21375, 711, 30.04920337, nan, nan,
#         nan, nan, nan, nan, nan],
#        ['21STCENMGM', '21st Century Management Service', 110375, 3879,
#         28.45083129, nan, nan, nan, nan, nan, nan, nan],
#        ['ALPHAGEO', 'Alphageo (India) Limited ', 232755, 8356,
#         27.85261268, nan, nan, nan, nan, nan, nan, nan],
#        ['UNIENTER', 'Uniphos Enterprised Limited', 162601, 7553,
#         21.52800212, nan, nan, nan, nan, nan, nan, nan],
#        ['JAGSNPHARM', 'Jagsonpal Pharmaceutical Limited', 1301892, 73134,
#         17.80141977, nan, nan, nan, nan, nan, nan, nan],
# ...

# %%
## print data into descending order

csv.sort_index(axis=0,ascending=False)
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 24    INDORAMA       Indo Rama Synthetic (India) Limited          679204
# 23   INTENTECH              Intense Technologies Limited         1252606
# 22      ALKALI                    Alkalis Metals Limited          157496
# 21    MUNJALAU            Munjal Auto Industries Limited          705322
# 20  BHAGYAPROP            Bhagyanagar Properties Limited          305594
# 19      PILITA             PIL ITALICA LIFESTYLE LIMITED         6864080
# 18        REPL          Rudrabhishek Enterprises Limited          660281
# 17    LAXMICOT                     Laxmi Costpin Limited          198503
# 16    ANDREWYU           Andrew Yule & Company & Limited         2408026
# 15        DSSL                Dynacons System & Solution          263641
# 14  PDMJEPAPER           Pudumjee Paper Products Limited         1316284
# 13  SHIVAMILLS                       Shiva Mills Limited          142943
# ...

# %%
csv["SYMBOL"][0] = "Python"
csv
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_9304\1783452764.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   csv["SYMBOL"][0] = "Python"
# ...

# %%
## using loc method to changes in row

csv.loc[0,"SYMBOL"] = "Java"
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0         Java                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
# loc method is used to get any data

csv.loc[[2,3],["SYMBOL","SECURITY"]]
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0         Java                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
csv.loc[:,["SYMBOL","SECURITY"]]
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0         Java                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
csv.loc[[2,3],:]
# Out:
#        SYMBOL                 SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 2     HINDCON  Hindcon Private Limited          304759          9248
# 3  GKWLIMITED              GKW Limited           21375           711
#
#       CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 2  32.953450         NaN         NaN         NaN         NaN         NaN
# 3  30.049203         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 10 Unnamed: 11
# 2          NaN
# 3          NaN         NaN

# %%
## iloc method

csv.iloc[0,1]
# Out:
# 'Electrotherm'

# %%
## it show 4 number row 
csv.iloc[4]
# Out:
# SYMBOL                                 21STCENMGM
# SECURITY          21st Century Management Service
# TODAY - VILUME                             110375
# AVG - VOLUME                                 3879
# CHANGE                                  28.450831
# Unnamed: 5                                    NaN
# Unnamed: 6                                    NaN
# Unnamed: 7                                    NaN
# Unnamed: 8                                    NaN
# Unnamed: 9                                    NaN
# Unnamed: 10                                   NaN
# Unnamed: 11                                   NaN
# Name: 4, dtype: object

# %%
# these will show 1 row of 3 column
csv.iloc[1,3]
# Out:
# np.int64(154)

# %%
## how to delete a column using drop method

csv.drop("SYMBOL",axis=1)
# Out:
#                                     SECURITY  TODAY - VILUME  AVG - VOLUME  \
# 0                               Electrotherm          473907          9457
# 1        N. B. I. Industrial Finance Company            5754           154
# 2                    Hindcon Private Limited          304759          9248
# 3                                GKW Limited           21375           711
# 4            21st Century Management Service          110375          3879
# 5                  Alphageo (India) Limited           232755          8356
# 6                Uniphos Enterprised Limited          162601          7553
# 7           Jagsonpal Pharmaceutical Limited         1301892         73134
# 8   SKM Egg Products Exportsn(India) Limited         1541130         87775
# 9              Swelect Energy System Limited          207954         12276
# 10                   Nahar Poly Film Limited          600043         38574
# ...

# %%
## how to remove or delete a row

csv.drop(0, axis=0)
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# 12        LINC                              Linc Limited           60551
# ...
