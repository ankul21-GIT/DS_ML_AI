# %% [markdown]
# ## Read CSV File

# %% [markdown]
# - A simple way to store big data set is to use csv file (comma seprated file).
#
# - CSV file contain plain text and well know format that can be read by everone including Pandas

# %%
import pandas as pd
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv")

# %%
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0    ELECTHERM                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SYMBOL          25 non-null     object
#  1   SECURITY        25 non-null     object
#  2   TODAY - VILUME  25 non-null     int64
#  3   AVG - VOLUME    25 non-null     int64
#  4   CHANGE          25 non-null     float64
#  5   Unnamed: 5      0 non-null      float64
#  6   Unnamed: 6      0 non-null      float64
#  7   Unnamed: 7      0 non-null      float64
#  8   Unnamed: 8      0 non-null      float64
#  9   Unnamed: 9      0 non-null      float64
#  10  Unnamed: 10     0 non-null      float64
#  11  Unnamed: 11     1 non-null      object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 2.5+ KB

# %%
csv.head()
# Out:
#        SYMBOL                             SECURITY  TODAY - VILUME  \
# 0   ELECTHERM                         Electrotherm          473907
# 1      NBIFIN  N. B. I. Industrial Finance Company            5754
# 2     HINDCON              Hindcon Private Limited          304759
# 3  GKWLIMITED                          GKW Limited           21375
# 4  21STCENMGM      21st Century Management Service          110375
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  50.110003         NaN         NaN         NaN         NaN
# 1           154  37.202586         NaN         NaN         NaN         NaN
# 2          9248  32.953450         NaN         NaN         NaN         NaN
# 3           711  30.049203         NaN         NaN         NaN         NaN
# 4          3879  28.450831         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# ...

# %%
csv.describe()
# Out:
#        TODAY - VILUME   AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  \
# count    2.500000e+01      25.000000  25.000000         0.0         0.0
# mean     8.009246e+05   71237.680000  17.900822         NaN         NaN
# std      1.395095e+06  139964.620859  10.796906         NaN         NaN
# min      5.754000e+03     154.000000   7.606862         NaN         NaN
# 25%      1.574960e+05    8356.000000  10.049911         NaN         NaN
# 50%      3.047590e+05   19069.000000  14.853673         NaN         NaN
# 75%      7.053220e+05   82307.000000  21.528002         NaN         NaN
# max      6.864080e+06  685602.000000  50.110003         NaN         NaN
#
#        Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# count         0.0         0.0         0.0          0.0
# mean          NaN         NaN         NaN          NaN
# std           NaN         NaN         NaN          NaN
# min           NaN         NaN         NaN          NaN
# ...

# %%
## method to find the first row using iloc method
print(csv.iloc[0])
# Out:
# SYMBOL               ELECTHERM
# SECURITY          Electrotherm
# TODAY - VILUME          473907
# AVG - VOLUME              9457
# CHANGE               50.110003
# Unnamed: 5                 NaN
# Unnamed: 6                 NaN
# Unnamed: 7                 NaN
# Unnamed: 8                 NaN
# Unnamed: 9                 NaN
# Unnamed: 10                NaN
# Unnamed: 11                NaN
# Name: 0, dtype: object

# %%
## nrow useful for getting any particulat row.
import pandas as pd
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", nrows=3)

# %%
csv
# Out:
#       SYMBOL                             SECURITY  TODAY - VILUME  \
# 0  ELECTHERM                         Electrotherm          473907
# 1     NBIFIN  N. B. I. Industrial Finance Company            5754
# 2    HINDCON              Hindcon Private Limited          304759
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  50.110003         NaN         NaN         NaN         NaN
# 1           154  37.202586         NaN         NaN         NaN         NaN
# 2          9248  32.953450         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# 1         NaN          NaN         NaN
# 2         NaN          NaN

# %%
## nrow useful for getting any particulat column.
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", usecols=["SYMBOL"])

# %%
csv
# Out:
#         SYMBOL
# 0    ELECTHERM
# 1       NBIFIN
# 2      HINDCON
# 3   GKWLIMITED
# 4   21STCENMGM
# 5     ALPHAGEO
# 6     UNIENTER
# 7   JAGSNPHARM
# 8   SKMEGGPROD
# 9   SWELELCTES
# 10   NAHARPOLY
# 11  PODDARHOUS
# 12        LINC
# 13  SHIVAMILLS
# 14  PDMJEPAPER
# 15        DSSL
# 16    ANDREWYU
# 17    LAXMICOT
# 18        REPL
# 19      PILITA
# 20  BHAGYAPROP
# 21    MUNJALAU
# 22      ALKALI
# 23   INTENTECH
# 24    INDORAMA

# %%
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv")
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0    ELECTHERM                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
print(csv['CHANGE'])
# Out:
# 0     50.110003
# 1     37.202586
# 2     32.953450
# 3     30.049203
# 4     28.450831
# 5     27.852613
# 6     21.528002
# 7     17.801420
# 8     17.557733
# 9     16.938733
# 10    15.555297
# 11    15.283833
# 12    14.853673
# 13    13.755541
# 14    12.892143
# 15    11.247963
# 16    10.641332
# 17    10.443312
# 18    10.049911
# 19    10.017751
# 20     9.987766
# 21     8.569312
# 22     8.563313
# 23     7.607959
# 24     7.606862
# Name: CHANGE, dtype: float64

# %%
csv['CHANGE'] = csv['CHANGE'] + 1

# %%
csv
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0    ELECTHERM                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
csv.head()
# Out:
#        SYMBOL                             SECURITY  TODAY - VILUME  \
# 0   ELECTHERM                         Electrotherm          473907
# 1      NBIFIN  N. B. I. Industrial Finance Company            5754
# 2     HINDCON              Hindcon Private Limited          304759
# 3  GKWLIMITED                          GKW Limited           21375
# 4  21STCENMGM      21st Century Management Service          110375
#
#    AVG - VOLUME     CHANGE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0          9457  51.110003         NaN         NaN         NaN         NaN
# 1           154  38.202586         NaN         NaN         NaN         NaN
# 2          9248  33.953450         NaN         NaN         NaN         NaN
# 3           711  31.049203         NaN         NaN         NaN         NaN
# 4          3879  29.450831         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0         NaN          NaN         NaN
# ...

# %%
print(csv[['SYMBOL', 'SECURITY', 'CHANGE']])
# Out:
#         SYMBOL                                  SECURITY     CHANGE
# 0    ELECTHERM                              Electrotherm  51.110003
# 1       NBIFIN       N. B. I. Industrial Finance Company  38.202586
# 2      HINDCON                   Hindcon Private Limited  33.953450
# 3   GKWLIMITED                               GKW Limited  31.049203
# 4   21STCENMGM           21st Century Management Service  29.450831
# 5     ALPHAGEO                 Alphageo (India) Limited   28.852613
# 6     UNIENTER               Uniphos Enterprised Limited  22.528002
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited  18.801420
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited  18.557733
# 9   SWELELCTES             Swelect Energy System Limited  17.938733
# 10   NAHARPOLY                   Nahar Poly Film Limited  16.555297
# 11  PODDARHOUS            Poddar Housing and Development  16.283833
# 12        LINC                              Linc Limited  15.853673
# ...

# %%
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", usecols=[1,2])
csv
# Out:
#                                     SECURITY  TODAY - VILUME
# 0                               Electrotherm          473907
# 1        N. B. I. Industrial Finance Company            5754
# 2                    Hindcon Private Limited          304759
# 3                                GKW Limited           21375
# 4            21st Century Management Service          110375
# 5                  Alphageo (India) Limited           232755
# 6                Uniphos Enterprised Limited          162601
# 7           Jagsonpal Pharmaceutical Limited         1301892
# 8   SKM Egg Products Exportsn(India) Limited         1541130
# 9              Swelect Energy System Limited          207954
# 10                   Nahar Poly Film Limited          600043
# 11            Poddar Housing and Development           46040
# 12                              Linc Limited           60551
# 13                       Shiva Mills Limited          142943
# ...

# %%
## These method is used for calling the columns
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv")
columns = csv.columns[[1, 3]]
print(csv[columns])
# Out:
#                                     SECURITY  AVG - VOLUME
# 0                               Electrotherm          9457
# 1        N. B. I. Industrial Finance Company           154
# 2                    Hindcon Private Limited          9248
# 3                                GKW Limited           711
# 4            21st Century Management Service          3879
# 5                  Alphageo (India) Limited           8356
# 6                Uniphos Enterprised Limited          7553
# 7           Jagsonpal Pharmaceutical Limited         73134
# 8   SKM Egg Products Exportsn(India) Limited         87775
# 9              Swelect Energy System Limited         12276
# 10                   Nahar Poly Film Limited         38574
# 11            Poddar Housing and Development          3012
# 12                              Linc Limited          4076
# 13                       Shiva Mills Limited         10391
# 14           Pudumjee Paper Products Limited        102646
# ...

# %%
# skip the row number 0 and row 3 we use skiprows method.
csv = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", skiprows=[0,3])
csv
# Out:
#      ELECTHERM                              Electrotherm   473907    9457  \
# 0       NBIFIN       N. B. I. Industrial Finance Company     5754     154
# 1   GKWLIMITED                               GKW Limited    21375     711
# 2   21STCENMGM           21st Century Management Service   110375    3879
# 3     ALPHAGEO                 Alphageo (India) Limited    232755    8356
# 4     UNIENTER               Uniphos Enterprised Limited   162601    7553
# 5   JAGSNPHARM          Jagsonpal Pharmaceutical Limited  1301892   73134
# 6   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited  1541130   87775
# 7   SWELELCTES             Swelect Energy System Limited   207954   12276
# 8    NAHARPOLY                   Nahar Poly Film Limited   600043   38574
# 9   PODDARHOUS            Poddar Housing and Development    46040    3012
# 10        LINC                              Linc Limited    60551    4076
# 11  SHIVAMILLS                       Shiva Mills Limited   142943   10391
# ...

# %%
## index_col method make SYMBOL to index
csv_2 = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", index_col=['SYMBOL'])
csv_2
# Out:
#                                             SECURITY  TODAY - VILUME  \
# SYMBOL
# ELECTHERM                               Electrotherm          473907
# NBIFIN           N. B. I. Industrial Finance Company            5754
# HINDCON                      Hindcon Private Limited          304759
# GKWLIMITED                               GKW Limited           21375
# 21STCENMGM           21st Century Management Service          110375
# ALPHAGEO                   Alphageo (India) Limited           232755
# UNIENTER                 Uniphos Enterprised Limited          162601
# JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# SWELELCTES             Swelect Energy System Limited          207954
# NAHARPOLY                    Nahar Poly Film Limited          600043
# PODDARHOUS            Poddar Housing and Development           46040
# ...

# %%
## Header parameter make header any row as you want
csv_2 = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", header=2)
csv_2
# Out:
#         NBIFIN       N. B. I. Industrial Finance Company     5754     154  \
# 0      HINDCON                   Hindcon Private Limited   304759    9248
# 1   GKWLIMITED                               GKW Limited    21375     711
# 2   21STCENMGM           21st Century Management Service   110375    3879
# 3     ALPHAGEO                 Alphageo (India) Limited    232755    8356
# 4     UNIENTER               Uniphos Enterprised Limited   162601    7553
# 5   JAGSNPHARM          Jagsonpal Pharmaceutical Limited  1301892   73134
# 6   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited  1541130   87775
# 7   SWELELCTES             Swelect Energy System Limited   207954   12276
# 8    NAHARPOLY                   Nahar Poly Film Limited   600043   38574
# 9   PODDARHOUS            Poddar Housing and Development    46040    3012
# 10        LINC                              Linc Limited    60551    4076
# 11  SHIVAMILLS                       Shiva Mills Limited   142943   10391
# ...

# %%
## name method is used for change the heading
csv_2 = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv",names=['col1','col2','ank3','sri4','sad5','sur6','None','chan','vol12'])
csv_2
# Out:
#                                                                             col1  \
# SYMBOL     SECURITY                                 TODAY - VILUME  AVG - VOLUME
# ELECTHERM  Electrotherm                             473907                  9457
# NBIFIN     N. B. I. Industrial Finance Company      5754                     154
# HINDCON    Hindcon Private Limited                  304759                  9248
# GKWLIMITED GKW Limited                              21375                    711
# 21STCENMGM 21st Century Management Service          110375                  3879
# ALPHAGEO   Alphageo (India) Limited                 232755                  8356
# UNIENTER   Uniphos Enterprised Limited              162601                  7553
# JAGSNPHARM Jagsonpal Pharmaceutical Limited         1301892                73134
# SKMEGGPROD SKM Egg Products Exportsn(India) Limited 1541130                87775
# SWELELCTES Swelect Energy System Limited            207954                 12276
# ...

# %%
## name method is used for change the heading
csv_2 = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv",header=None)
csv_2
# Out:
#             0                                         1               2   \
# 0       SYMBOL                                  SECURITY  TODAY - VILUME
# 1    ELECTHERM                              Electrotherm          473907
# 2       NBIFIN       N. B. I. Industrial Finance Company            5754
# 3      HINDCON                   Hindcon Private Limited          304759
# 4   GKWLIMITED                               GKW Limited           21375
# 5   21STCENMGM           21st Century Management Service          110375
# 6     ALPHAGEO                 Alphageo (India) Limited           232755
# 7     UNIENTER               Uniphos Enterprised Limited          162601
# 8   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 9   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 10  SWELELCTES             Swelect Energy System Limited          207954
# 11   NAHARPOLY                   Nahar Poly Film Limited          600043
# ...

# %%
## giving prefix parameter
import pandas as pd

df = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", header=None)

# Rename columns with a prefix
df.columns = [f'col{i}' for i in range(df.shape[1])]

print(df)
# Out:
#           col0                                      col1            col2  \
# 0       SYMBOL                                  SECURITY  TODAY - VILUME
# 1    ELECTHERM                              Electrotherm          473907
# 2       NBIFIN       N. B. I. Industrial Finance Company            5754
# 3      HINDCON                   Hindcon Private Limited          304759
# 4   GKWLIMITED                               GKW Limited           21375
# 5   21STCENMGM           21st Century Management Service          110375
# 6     ALPHAGEO                 Alphageo (India) Limited           232755
# 7     UNIENTER               Uniphos Enterprised Limited          162601
# 8   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 9   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 10  SWELELCTES             Swelect Energy System Limited          207954
# 11   NAHARPOLY                   Nahar Poly Film Limited          600043
# ...

# %%
csv_2 = pd.read_csv(r"C:\Users\ankul\Downloads\ank.csv", dtype={"Today-Valume":"float"})
csv_2
# Out:
#         SYMBOL                                  SECURITY  TODAY - VILUME  \
# 0    ELECTHERM                              Electrotherm          473907
# 1       NBIFIN       N. B. I. Industrial Finance Company            5754
# 2      HINDCON                   Hindcon Private Limited          304759
# 3   GKWLIMITED                               GKW Limited           21375
# 4   21STCENMGM           21st Century Management Service          110375
# 5     ALPHAGEO                 Alphageo (India) Limited           232755
# 6     UNIENTER               Uniphos Enterprised Limited          162601
# 7   JAGSNPHARM          Jagsonpal Pharmaceutical Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Exportsn(India) Limited         1541130
# 9   SWELELCTES             Swelect Energy System Limited          207954
# 10   NAHARPOLY                   Nahar Poly Film Limited          600043
# 11  PODDARHOUS            Poddar Housing and Development           46040
# ...
