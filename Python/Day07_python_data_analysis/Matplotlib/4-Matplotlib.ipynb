# %% [markdown]
# ## Histogram Plot

# %% [markdown]
# import matplotlib.pyplot as plt
#
# x=[]
#
# plt.hist(x)
#
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [29 48 19 41 13 58 22 10 58 36 51 50 18 52 51 43 49 26 34 31 44 46 19 37
#  54 14 51 49 34 58 24 23 44 57 50 11 40 36 18 44 18 54 48 54 40 39 56 53
#  38 52]

# %%
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

plt.hist(no)
plt.show()

# %%
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

plt.hist(no,color="y")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## bins parameter show how the range of the data is divided

no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="y",edgecolor="r")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,"auto",(0,200),edgecolor="r")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# C:\Users\ankul\AppData\Local\Temp\ipykernel_12956\1248759876.py:8: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no,"auto",(0,200),edgecolor="r")

# %%
## cumulative parameters reverse the order.

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",edgecolor="r",cumulative=-1)
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## bottom parameters.

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",edgecolor="r",bottom=10)
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## align parameters.

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",edgecolor="r",align="left") ## we can also used align = left adn right
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## histtype parameters.

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",histtype="step")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## histtype parameters.

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",histtype="stepfilled")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",histtype="barstacked")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## orientation method used for vertical to horizontal cahnging
import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",orientation="horizontal")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## rwidth change in x axis

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",rwidth=0.8)
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## log method change the table into log or create a table into the form of the log.
import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",log=True)
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
## label parameter

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",label="Python")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()  ## used for the label method
plt.show()

# %%
## axvline show the graph is divided into two part left hand side and right hand

import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",label="Python")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.axvline(45, color="g",label="line")

plt.legend()  ## used for the label method
plt.show()

# %%
## grid method customize the grid line 
import matplotlib.pyplot as plt
no = [29, 48, 19, 41, 13, 58, 22, 10, 58, 36, 51, 50, 18, 52, 51, 43, 49, 26, 34, 31, 44, 46, 19, 37,
 54, 14, 51, 49, 34, 58, 24, 23, 44, 57, 50, 11, 40, 36, 18, 44, 18, 54, 48, 54, 40, 39, 56, 53,
 38, 52]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no,color="b",bins=l,edgecolor="r",label="Python")
plt.title("Histogram")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.axvline(45, color="g",label="line")

plt.legend()  ## used for the label method
plt.grid()
plt.show()
